// %% [markdown]
// # GoNB ECharts Examples
//
// They are adaptations of examples in [Apache EChart](https://echarts.apache.org/v4/examples/en/index.html) and in [go-echarts library](https://github.com/go-echarts/examples)
//
// The first cell below redirects the `gonb-echarts` and `gonb` libraries to the local disk repository -- this was used during development but feel free to comment it out.

// %%
!*go mod edit --replace github.com/janpfeifer/gonb-echarts=${HOME}/Projects/gonb-echarts
!*go mod edit --replace github.com/janpfeifer/gonb=${HOME}/Projects/gonb

// %% [markdown]
// ## Bar Chart

// %%
import (
	"math/rand"
	"github.com/go-echarts/go-echarts/v2/charts"
	"github.com/go-echarts/go-echarts/v2/opts"
    gonb_echarts "github.com/janpfeifer/gonb-echarts"
    "github.com/janpfeifer/must"   
)

// generate random data for bar chart
func generateBarItems() []opts.BarData {
	items := make([]opts.BarData, 0)
	for i := 0; i < 7; i++ {
		items = append(items, opts.BarData{Value: rand.Intn(300)})
	}
	return items
}

%%
bar := charts.NewBar()
// set some global options like Title/Legend/ToolTip or anything else
bar.SetGlobalOptions(charts.WithTitleOpts(opts.Title{
    Title:    "My first bar chart generated by go-echarts",
    Subtitle: "It's extremely easy to use, right?",
}))

// Put data into instance
bar.SetXAxis([]string{"Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"}).
    AddSeries("Category A", generateBarItems()).
    AddSeries("Category B", generateBarItems())

// Display
must.M(gonb_echarts.Display(bar, "width: 1024px; height:400px; background: white;"))
// Out:
// <div id="HxFHITecdMJX" style="width: 1024px; height:400px; background: white;"></div><script>
// (() => {
// 	let echartsFn = function() {
//
//
//     "use strict";
//     let goecharts_HxFHITecdMJX = echarts.init(document.getElementById('HxFHITecdMJX'), "white");
//     let option_HxFHITecdMJX = {"animation":true,"color":["#5470c6","#91cc75","#fac858","#ee6666","#73c0de","#3ba272","#fc8452","#9a60b4","#ea7ccc"],"legend":{"show":true,"type":""},"series":[{"name":"Category A","type":"bar","smooth":false,"connectNulls":false,"showSymbol":false,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":false,"data":[{"value":265},{"value":81},{"value":143},{"value":24},{"value":164},{"value":114},{"value":191}]},{"name":"Category B","type":"bar","smooth":false,"connectNulls":false,"showSymbol":false,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":false,"data":[{"value":161},{"value":3},{"value":147},{"value":92},{"value":232},{"value":275},{"value":40}]}],"title":{"text":"My first bar chart generated by go-echarts","subtext":"It's extremely easy to use, right?"},"tooltip":{"show":false},"xAxis":[{"data":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]}],"yAxis":[{}]}
// ;
//
// 	let action_HxFHITecdMJX = {"areas":{},"type":""}
// ;
//
//     goecharts_HxFHITecdMJX.setOption(option_HxFHITecdMJX);
//  	goecharts_HxFHITecdMJX.dispatchAction(action_HxFHITecdMJX);
//
//
// 	}
//
// 	let echartsSrcs = [
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/echarts.min.js",
//
// 	];
//
// 	function loadScriptsThenExecute(scripts, fn) {
// 		if (scripts.length == 0) {
// 			// Nothing to load, execute immediately.
// 			fn();
// 			return;
// 		}
//
// 		// Keep track of loaded scripts
// 		let loadedCount = 0;
// 		const head = document.head;
//
// 		// Function to handle successful script loading
// 		const scriptLoaded = () => {
// 			loadedCount++;
// 			if (loadedCount === scripts.length) {
// 				fn(); // Execute the callback function when all scripts are loaded
// 			}
// 		};
//
// 		for (const src of scripts) {
// 			// Check if script is already loaded
// 			const existingScript = document.querySelector('script[src="'+src+'"]');
// 			if (existingScript) {
// 				// Script already loaded.
// 				scriptLoaded(); // Proceed as if loaded
// 			} else if (typeof requirejs === "function") {
// 				require([src], function(loadedModule) {
//         			// Note: 'loadedModule' will contain the exports from the script, if any.
//         			scriptLoaded();
// 				});
// 			} else {
// 				// Create the script element
// 				const script = document.createElement('script');
// 				script.async = false;  // Order matters, this must be false.
// 				script.src = src;
// 				script.onload = scriptLoaded;
// 				script.onerror = () => console.error('Failed to load script: '+src);
// 				head.appendChild(script);
// 			}
// 		}
// 	}
//
// 	if (typeof requirejs === "function") {
// 		console.log("Using RequireJS");
// 		let src = echartsSrcs.shift();  // The first source is echarts, which must be loaded with RequireJS.
// 		// Use RequireJS to load module.
// 		let srcWithoutExtension = src.substring(0, src.lastIndexOf(".js"));
// 		requirejs.config({
// 			paths: {
// 				'echarts': srcWithoutExtension
// 			}
// 		});
// 		require(['echarts'], function(echarts) {
// 			window.echarts = echarts;  // Define echarts globally.
// 			loadScriptsThenExecute(echartsSrcs, echartsFn);  // Load rest of scripts.
// 		});
// 		return
//
// 	} else {
// 		console.log("Not using RequireJS");
// 		loadScriptsThenExecute(echartsSrcs, echartsFn);
// 	}
//
// })();
// </script>

// %% [markdown]
// ## Stacked Lines

// %%
func toLineData[In any](data []In) []opts.LineData {
    r := make([]opts.LineData, len(data))
    for ii, v := range data {
        r[ii].Value = v 
    }
    return r
}

%%
stackedLine := charts.NewLine()
stackedLine.SetGlobalOptions(
    charts.WithTitleOpts(opts.Title{Title: "Stacked Line",}), 
    charts.WithTooltipOpts(opts.Tooltip{Show:true, Trigger: "axis"}),
)
seriesOpt := charts.WithLineChartOpts(opts.LineChart{
    Stack: "Total",
    ShowSymbol: true,
})

stackedLine.
    SetGlobalOptions(charts.WithYAxisOpts(opts.YAxis{Type: "value"}))
stackedLine.
    SetXAxis([]string{"Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"}). 
    AddSeries("Email", toLineData([]int{120, 132, 101, 134, 90, 230, 210}), seriesOpt).
    AddSeries("Union Ads", toLineData([]int{220, 182, 191, 234, 290, 330, 310}), seriesOpt).
    AddSeries("Video Ads", toLineData([]int{150, 232, 201, 154, 190, 330, 410}), seriesOpt).
    AddSeries("Direct", toLineData([]int{320, 332, 301, 334, 390, 330, 320}), seriesOpt).
    AddSeries("Search Engine", toLineData([]int{820, 932, 901, 934, 1290, 1330, 1320}), seriesOpt)

must.M(gonb_echarts.Display(stackedLine, "width: 1024px; height:400px; background: white;"))
// Out:
// <div id="GldipVGMLljz" style="width: 1024px; height:400px; background: white;"></div><script>
// (() => {
// 	let echartsFn = function() {
//
//
//     "use strict";
//     let goecharts_GldipVGMLljz = echarts.init(document.getElementById('GldipVGMLljz'), "white");
//     let option_GldipVGMLljz = {"animation":true,"color":["#5470c6","#91cc75","#fac858","#ee6666","#73c0de","#3ba272","#fc8452","#9a60b4","#ea7ccc"],"legend":{"show":true,"type":""},"series":[{"name":"Email","type":"line","stack":"Total","smooth":false,"connectNulls":false,"showSymbol":true,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":true,"data":[{"value":120,"XAxisIndex":0,"YAxisIndex":0},{"value":132,"XAxisIndex":0,"YAxisIndex":0},{"value":101,"XAxisIndex":0,"YAxisIndex":0},{"value":134,"XAxisIndex":0,"YAxisIndex":0},{"value":90,"XAxisIndex":0,"YAxisIndex":0},{"value":230,"XAxisIndex":0,"YAxisIndex":0},{"value":210,"XAxisIndex":0,"YAxisIndex":0}]},{"name":"Union Ads","type":"line","stack":"Total","smooth":false,"connectNulls":false,"showSymbol":true,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":true,"data":[{"value":220,"XAxisIndex":0,"YAxisIndex":0},{"value":182,"XAxisIndex":0,"YAxisIndex":0},{"value":191,"XAxisIndex":0,"YAxisIndex":0},{"value":234,"XAxisIndex":0,"YAxisIndex":0},{"value":290,"XAxisIndex":0,"YAxisIndex":0},{"value":330,"XAxisIndex":0,"YAxisIndex":0},{"value":310,"XAxisIndex":0,"YAxisIndex":0}]},{"name":"Video Ads","type":"line","stack":"Total","smooth":false,"connectNulls":false,"showSymbol":true,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":true,"data":[{"value":150,"XAxisIndex":0,"YAxisIndex":0},{"value":232,"XAxisIndex":0,"YAxisIndex":0},{"value":201,"XAxisIndex":0,"YAxisIndex":0},{"value":154,"XAxisIndex":0,"YAxisIndex":0},{"value":190,"XAxisIndex":0,"YAxisIndex":0},{"value":330,"XAxisIndex":0,"YAxisIndex":0},{"value":410,"XAxisIndex":0,"YAxisIndex":0}]},{"name":"Direct","type":"line","stack":"Total","smooth":false,"connectNulls":false,"showSymbol":true,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":true,"data":[{"value":320,"XAxisIndex":0,"YAxisIndex":0},{"value":332,"XAxisIndex":0,"YAxisIndex":0},{"value":301,"XAxisIndex":0,"YAxisIndex":0},{"value":334,"XAxisIndex":0,"YAxisIndex":0},{"value":390,"XAxisIndex":0,"YAxisIndex":0},{"value":330,"XAxisIndex":0,"YAxisIndex":0},{"value":320,"XAxisIndex":0,"YAxisIndex":0}]},{"name":"Search Engine","type":"line","stack":"Total","smooth":false,"connectNulls":false,"showSymbol":true,"waveAnimation":false,"renderLabelForZeroData":false,"selectedMode":false,"animation":true,"data":[{"value":820,"XAxisIndex":0,"YAxisIndex":0},{"value":932,"XAxisIndex":0,"YAxisIndex":0},{"value":901,"XAxisIndex":0,"YAxisIndex":0},{"value":934,"XAxisIndex":0,"YAxisIndex":0},{"value":1290,"XAxisIndex":0,"YAxisIndex":0},{"value":1330,"XAxisIndex":0,"YAxisIndex":0},{"value":1320,"XAxisIndex":0,"YAxisIndex":0}]}],"title":{"text":"Stacked Line"},"tooltip":{"show":true,"trigger":"axis"},"xAxis":[{"data":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]}],"yAxis":[{"type":"value"}]}
// ;
//
// 	let action_GldipVGMLljz = {"areas":{},"type":""}
// ;
//
//     goecharts_GldipVGMLljz.setOption(option_GldipVGMLljz);
//  	goecharts_GldipVGMLljz.dispatchAction(action_GldipVGMLljz);
//
//
// 	}
//
// 	let echartsSrcs = [
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/echarts.min.js",
//
// 	];
//
// 	function loadScriptsThenExecute(scripts, fn) {
// 		if (scripts.length == 0) {
// 			// Nothing to load, execute immediately.
// 			fn();
// 			return;
// 		}
//
// 		// Keep track of loaded scripts
// 		let loadedCount = 0;
// 		const head = document.head;
//
// 		// Function to handle successful script loading
// 		const scriptLoaded = () => {
// 			loadedCount++;
// 			if (loadedCount === scripts.length) {
// 				fn(); // Execute the callback function when all scripts are loaded
// 			}
// 		};
//
// 		for (const src of scripts) {
// 			// Check if script is already loaded
// 			const existingScript = document.querySelector('script[src="'+src+'"]');
// 			if (existingScript) {
// 				// Script already loaded.
// 				scriptLoaded(); // Proceed as if loaded
// 			} else if (typeof requirejs === "function") {
// 				require([src], function(loadedModule) {
//         			// Note: 'loadedModule' will contain the exports from the script, if any.
//         			scriptLoaded();
// 				});
// 			} else {
// 				// Create the script element
// 				const script = document.createElement('script');
// 				script.async = false;  // Order matters, this must be false.
// 				script.src = src;
// 				script.onload = scriptLoaded;
// 				script.onerror = () => console.error('Failed to load script: '+src);
// 				head.appendChild(script);
// 			}
// 		}
// 	}
//
// 	if (typeof requirejs === "function") {
// 		console.log("Using RequireJS");
// 		let src = echartsSrcs.shift();  // The first source is echarts, which must be loaded with RequireJS.
// 		// Use RequireJS to load module.
// 		let srcWithoutExtension = src.substring(0, src.lastIndexOf(".js"));
// 		requirejs.config({
// 			paths: {
// 				'echarts': srcWithoutExtension
// 			}
// 		});
// 		require(['echarts'], function(echarts) {
// 			window.echarts = echarts;  // Define echarts globally.
// 			loadScriptsThenExecute(echartsSrcs, echartsFn);  // Load rest of scripts.
// 		});
// 		return
//
// 	} else {
// 		console.log("Not using RequireJS");
// 		loadScriptsThenExecute(echartsSrcs, echartsFn);
// 	}
//
// })();
// </script>

// %% [markdown]
// ## Polar Example
//
// Not working yet, see issue [go-echarts #414](https://github.com/go-echarts/go-echarts/issues/414)

// %%
import "math"

%%
const numPoints = 100
data := make([]opts.LineData, numPoints)
for ii := range 100 {
    theta := (float64(ii) / numPoints) * 360.0;
    r := 5 * (1.0 + math.Sin((theta / 180) * math.Pi));
    data[ii] = opts.LineData{Value: []float64{r, theta}}
}

polar := charts.NewLine()
polar.SetGlobalOptions(
    charts.WithTitleOpts(opts.Title{Title: "Two Value-Axes in Polar",}), 
    charts.WithPolarOps(opts.Polar{
        Tooltip: opts.Tooltip{
            Show: true,
            Trigger: "axis",
            AxisPointer: &opts.AxisPointer{Type: "cross"},
        },
    }),
    charts.WithAngleAxisOps(opts.AngleAxis{
        PolarAxisBase: opts.PolarAxisBase{
            Type: "value",
            StartAngle: 0.0,
        },
    }),
    charts.WithRadiusAxisOps(opts.RadiusAxis{
        PolarAxisBase: opts.PolarAxisBase{
            Type: "value",
            PolarIndex: 1,
        },
    }),
)
polar.AddSeries(
    "line", data, charts.WithCoordinateSystem("polar"))
// must.M(gonb_echarts.Display(polar, "width: 1024px; height:400px; background: white;"))

// %% [markdown]
// ## Geo Example

// %%
import (
	"io"
	"math/rand"
	"os"

    "github.com/janpfeifer/gonb/gonbui"
    gonb_echarts "github.com/janpfeifer/gonb-echarts"
    "github.com/janpfeifer/must"   
	"github.com/go-echarts/go-echarts/v2/charts"
	"github.com/go-echarts/go-echarts/v2/components"
	"github.com/go-echarts/go-echarts/v2/opts"
	"github.com/go-echarts/go-echarts/v2/types"
)

var geoData = []opts.GeoData{
	{Name: "北京", Value: []float64{116.40, 39.90, float64(rand.Intn(100))}},
	{Name: "上海", Value: []float64{121.47, 31.23, float64(rand.Intn(100))}},
	{Name: "重庆", Value: []float64{106.55, 29.56, float64(rand.Intn(100))}},
	{Name: "武汉", Value: []float64{114.31, 30.52, float64(rand.Intn(100))}},
	{Name: "台湾", Value: []float64{121.30, 25.03, float64(rand.Intn(100))}},
	{Name: "香港", Value: []float64{114.17, 22.28, float64(rand.Intn(100))}},
}

var guangdongData = []opts.GeoData{
	{Name: "汕头", Value: []float64{116.69, 23.39, float64(rand.Intn(100))}},
	{Name: "深圳", Value: []float64{114.07, 22.62, float64(rand.Intn(100))}},
	{Name: "广州", Value: []float64{113.23, 23.16, float64(rand.Intn(100))}},
}

func geoBase() *charts.Geo {
	geo := charts.NewGeo()
	geo.SetGlobalOptions(
		charts.WithTitleOpts(opts.Title{Title: "basic geo example"}),
		charts.WithGeoComponentOpts(opts.GeoComponent{
			Map:       "china",
			ItemStyle: &opts.ItemStyle{Color: "#006666"},
		}),
	)

	geo.AddSeries("geo", types.ChartEffectScatter, geoData,
		charts.WithRippleEffectOpts(opts.RippleEffect{
			Period:    4,
			Scale:     6,
			BrushType: "stroke",
		}),
	)
	return geo
}

func geoGuangdong() *charts.Geo {
	geo := charts.NewGeo()
	geo.SetGlobalOptions(
		charts.WithTitleOpts(opts.Title{Title: "Guangdong province"}),
		charts.WithGeoComponentOpts(opts.GeoComponent{
			Map: "广东",
		}),
		charts.WithVisualMapOpts(opts.VisualMap{
			Calculable: true,
			InRange: &opts.VisualMapInRange{
				Color: []string{"#50a3ba", "#eac736", "#d94e5d"},
			},
		}),
	)

	geo.AddSeries("geo", types.ChartScatter, guangdongData)
	return geo
}

type GeoExamples struct{}

%%
content := []string{
    must.M1(gonb_echarts.DisplayContent(geoBase(), "width: 100%; height:400px; background: white;")),
    must.M1(gonb_echarts.DisplayContent(geoGuangdong(), "width: 100%; height:400px; background: white;")),
}
gonbui.DisplayHtmlf(`<div style="display: flex">%s%s</div>`, content[0], content[1])
// Out:
// <div style="display: flex"><div id="vPVmdHMZLceO" style="width: 100%; height:400px; background: white;"></div><script>
// (() => {
// 	let echartsFn = function() {
//
//
//     "use strict";
//     let goecharts_vPVmdHMZLceO = echarts.init(document.getElementById('vPVmdHMZLceO'), "white");
//     let option_vPVmdHMZLceO = {"animation":true,"color":["#5470c6","#91cc75","#fac858","#ee6666","#73c0de","#3ba272","#fc8452","#9a60b4","#ea7ccc"],"geo":{"map":"china","itemStyle":{"color":"#006666"}},"legend":{"show":true,"type":""},"series":[{"name":"geo","type":"effectScatter","smooth":false,"connectNulls":false,"showSymbol":false,"waveAnimation":false,"coordinateSystem":"geo","renderLabelForZeroData":false,"selectedMode":false,"animation":false,"data":[{"name":"北京","value":[116.4,39.9,11]},{"name":"上海","value":[121.47,31.23,75]},{"name":"重庆","value":[106.55,29.56,89]},{"name":"武汉","value":[114.31,30.52,62]},{"name":"台湾","value":[121.3,25.03,61]},{"name":"香港","value":[114.17,22.28,24]}],"rippleEffect":{"period":4,"scale":6,"brushType":"stroke"}}],"title":{"text":"basic geo example"},"tooltip":{"show":false,"formatter":function (params) {return params.name + ' : ' + params.value[2];}}}
// ;
//
// 	let action_vPVmdHMZLceO = {"areas":{},"type":""}
// ;
//
//     goecharts_vPVmdHMZLceO.setOption(option_vPVmdHMZLceO);
//  	goecharts_vPVmdHMZLceO.dispatchAction(action_vPVmdHMZLceO);
//
//
// 	}
//
// 	let echartsSrcs = [
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/echarts.min.js",
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/maps/china.js",
//
// 	];
//
// 	function loadScriptsThenExecute(scripts, fn) {
// 		if (scripts.length == 0) {
// 			// Nothing to load, execute immediately.
// 			fn();
// 			return;
// 		}
//
// 		// Keep track of loaded scripts
// 		let loadedCount = 0;
// 		const head = document.head;
//
// 		// Function to handle successful script loading
// 		const scriptLoaded = () => {
// 			loadedCount++;
// 			if (loadedCount === scripts.length) {
// 				fn(); // Execute the callback function when all scripts are loaded
// 			}
// 		};
//
// 		for (const src of scripts) {
// 			// Check if script is already loaded
// 			const existingScript = document.querySelector('script[src="'+src+'"]');
// 			if (existingScript) {
// 				// Script already loaded.
// 				scriptLoaded(); // Proceed as if loaded
// 			} else if (typeof requirejs === "function") {
// 				require([src], function(loadedModule) {
//         			// Note: 'loadedModule' will contain the exports from the script, if any.
//         			scriptLoaded();
// 				});
// 			} else {
// 				// Create the script element
// 				const script = document.createElement('script');
// 				script.async = false;  // Order matters, this must be false.
// 				script.src = src;
// 				script.onload = scriptLoaded;
// 				script.onerror = () => console.error('Failed to load script: '+src);
// 				head.appendChild(script);
// 			}
// 		}
// 	}
//
// 	if (typeof requirejs === "function") {
// 		console.log("Using RequireJS");
// 		let src = echartsSrcs.shift();  // The first source is echarts, which must be loaded with RequireJS.
// 		// Use RequireJS to load module.
// 		let srcWithoutExtension = src.substring(0, src.lastIndexOf(".js"));
// 		requirejs.config({
// 			paths: {
// 				'echarts': srcWithoutExtension
// 			}
// 		});
// 		require(['echarts'], function(echarts) {
// 			window.echarts = echarts;  // Define echarts globally.
// 			loadScriptsThenExecute(echartsSrcs, echartsFn);  // Load rest of scripts.
// 		});
// 		return
//
// 	} else {
// 		console.log("Not using RequireJS");
// 		loadScriptsThenExecute(echartsSrcs, echartsFn);
// 	}
//
// })();
// </script><div id="KADHyeMOWrJY" style="width: 100%; height:400px; background: white;"></div><script>
// (() => {
// 	let echartsFn = function() {
//
//
//     "use strict";
//     let goecharts_KADHyeMOWrJY = echarts.init(document.getElementById('KADHyeMOWrJY'), "white");
//     let option_KADHyeMOWrJY = {"animation":true,"color":["#5470c6","#91cc75","#fac858","#ee6666","#73c0de","#3ba272","#fc8452","#9a60b4","#ea7ccc"],"geo":{"map":"广东"},"legend":{"show":true,"type":""},"series":[{"name":"geo","type":"scatter","smooth":false,"connectNulls":false,"showSymbol":false,"waveAnimation":false,"coordinateSystem":"geo","renderLabelForZeroData":false,"selectedMode":false,"animation":false,"data":[{"name":"汕头","value":[116.69,23.39,58]},{"name":"深圳","value":[114.07,22.62,54]},{"name":"广州","value":[113.23,23.16,83]}]}],"title":{"text":"Guangdong province"},"tooltip":{"show":false,"formatter":function (params) {return params.name + ' : ' + params.value[2];}},"visualMap":[{"calculable":true,"inRange":{"color":["#50a3ba","#eac736","#d94e5d"]},"show":false}]}
// ;
//
// 	let action_KADHyeMOWrJY = {"areas":{},"type":""}
// ;
//
//     goecharts_KADHyeMOWrJY.setOption(option_KADHyeMOWrJY);
//  	goecharts_KADHyeMOWrJY.dispatchAction(action_KADHyeMOWrJY);
//
//
// 	}
//
// 	let echartsSrcs = [
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/echarts.min.js",
//
// 		"https://go-echarts.github.io/go-echarts-assets/assets/maps/guangdong.js",
//
// 	];
//
// 	function loadScriptsThenExecute(scripts, fn) {
// 		if (scripts.length == 0) {
// 			// Nothing to load, execute immediately.
// 			fn();
// 			return;
// 		}
//
// 		// Keep track of loaded scripts
// 		let loadedCount = 0;
// 		const head = document.head;
//
// 		// Function to handle successful script loading
// 		const scriptLoaded = () => {
// 			loadedCount++;
// 			if (loadedCount === scripts.length) {
// 				fn(); // Execute the callback function when all scripts are loaded
// 			}
// 		};
//
// 		for (const src of scripts) {
// 			// Check if script is already loaded
// 			const existingScript = document.querySelector('script[src="'+src+'"]');
// 			if (existingScript) {
// 				// Script already loaded.
// 				scriptLoaded(); // Proceed as if loaded
// 			} else if (typeof requirejs === "function") {
// 				require([src], function(loadedModule) {
//         			// Note: 'loadedModule' will contain the exports from the script, if any.
//         			scriptLoaded();
// 				});
// 			} else {
// 				// Create the script element
// 				const script = document.createElement('script');
// 				script.async = false;  // Order matters, this must be false.
// 				script.src = src;
// 				script.onload = scriptLoaded;
// 				script.onerror = () => console.error('Failed to load script: '+src);
// 				head.appendChild(script);
// 			}
// 		}
// 	}
//
// 	if (typeof requirejs === "function") {
// 		console.log("Using RequireJS");
// 		let src = echartsSrcs.shift();  // The first source is echarts, which must be loaded with RequireJS.
// 		// Use RequireJS to load module.
// 		let srcWithoutExtension = src.substring(0, src.lastIndexOf(".js"));
// 		requirejs.config({
// 			paths: {
// 				'echarts': srcWithoutExtension
// 			}
// 		});
// 		require(['echarts'], function(echarts) {
// 			window.echarts = echarts;  // Define echarts globally.
// 			loadScriptsThenExecute(echartsSrcs, echartsFn);  // Load rest of scripts.
// 		});
// 		return
//
// 	} else {
// 		console.log("Not using RequireJS");
// 		loadScriptsThenExecute(echartsSrcs, echartsFn);
// 	}
//
// })();
// </script></div>
